# %%
import pandas as pd

# %% [markdown]
# ### Welcome to the Apply Challenge

# %%
link = 'https://raw.githubusercontent.com/chriszapp/datasets/main/books.csv'
books = pd.read_csv(link, nrows = 13)
books.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
# Firstly, have a look at the dataset
books.shape
# Out:
# (13, 12)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              13 non-null     int64
#  1   title               13 non-null     object
#  2   authors             13 non-null     object
#  3   average_rating      13 non-null     float64
#  4   isbn                13 non-null     object
#  5   isbn13              13 non-null     int64
#  6   language_code       13 non-null     object
#  7     num_pages         13 non-null     int64
#  8   ratings_count       13 non-null     int64
#  9   text_reviews_count  13 non-null     int64
#  10  publication_date    13 non-null     object
#  11  publisher           13 non-null     object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.3+ KB

# %%
# Mission 1: use apply to create a new column called 'reviews_opinion': if the ratings is between 4.5 and 5, the reviews_opinion is 'very good';
# if the rating is between 4 and 4.5, the reviews_opinion is 'good'; if the rating is between 3 and 4, the reviews_opinions will be 'neutral';
# if the rating is up to 3 the reviews_opinion is going to be 'bad'

# Add your code here
def reviews_op(rating):
    if rating >= 4.5:
      return "very good"
    elif rating >=4:
      return "good"
    elif rating >= 3:
      return "neutral"
    else:
      return "bad"


books["reviews_opinion"] = books["average_rating"].apply(reviews_op)

print(books.head(30).to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |

# %%
# Mission 2: using apply with a function, create a column with the number of authors per book
# (note that in the column 'authors', each name of the author is divided with the character '/')

# Add your code here
def authors_function(authors):
  split_names = authors.split("/")
  return len(split_names)

books["NB_Authors_Func"] = books["authors"].apply(authors_function)

print(books.to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |   NB_Authors_Func |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|------------------:|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |                 2 |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |                 2 |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |                 1 |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |                 2 |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |                 2 |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |                 1 |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |                 1 |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |                 1 |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |                 1 |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |                 1 |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |                 2 |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |                 1 |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |                 1 |

# %%
# Mission 3: rewrite the same task as Mission 2 using the lamdba function

# Add your code here
authors_lambda = lambda authors : len(authors.split("/"))
books["NB_Authors_lambda"] = books["authors"].apply(authors_lambda)

print(books.to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |   NB_Authors_Func |   NB_Authors_lambda |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|------------------:|--------------------:|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |                 2 |                   2 |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |                 2 |                   2 |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |                 1 |                   1 |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |                 2 |                   2 |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |                 2 |                   2 |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |                 1 |                   1 |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |                 1 |                   1 |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |                 1 |                   1 |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |                 1 |                   1 |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |                 1 |                   1 |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |                 2 |                   2 |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |                 1 |                   1 |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |                 1 |                   1 |

# %%
# Mission 4: create a column 'comment_ration'.
# Use the columns 'ratings_count' and 'text_reviews_count' to calculate the percentage of how many text review per reviews are per book:
# percentage = text / reviews * 100
# Use the mathematical operations between columns

# Add your code here

books["comment_ratio"]= round((books["text_reviews_count"] / books["ratings_count"]) * 100, 2)

print(books.to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |   NB_Authors_Func |   NB_Authors_lambda |   comment_ratio |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|------------------:|--------------------:|----------------:|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |                 2 |                   2 |            1.32 |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |                 2 |                   2 |            1.36 |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |                 1 |                   1 |            3.85 |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |                 2 |                   2 |            1.55 |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |                 2 |                   2 |            0.4  |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |                 1 |                   1 |            5.26 |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |                 1 |                   1 |            2.86 |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |                 1 |                   1 |            7    |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |                 1 |                   1 |            1.63 |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |                 1 |                   1 |            9.33 |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |                 2 |                   2 |           19.98 |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |                 1 |                   1 |            6.78 |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |                 1 |                   1 |            3.78 |

# %%
# Mission 5: obtain the same result of Mission 4 using apply with a function.
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here
def ratio_func(row):
  return round((row["text_reviews_count"] / row["ratings_count"]) * 100, 2)

col_books = ["text_reviews_count", "ratings_count"]
books["ratio_func"] = books.apply(ratio_func, axis = 1)

print(books.to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |   NB_Authors_Func |   NB_Authors_lambda |   comment_ratio |   ratio_func |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|------------------:|--------------------:|----------------:|-------------:|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |                 2 |                   2 |            1.32 |         1.32 |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |                 2 |                   2 |            1.36 |         1.36 |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |                 1 |                   1 |            3.85 |         3.85 |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |                 2 |                   2 |            1.55 |         1.55 |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |                 2 |                   2 |            0.4  |         0.4  |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |                 1 |                   1 |            5.26 |         5.26 |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |                 1 |                   1 |            2.86 |         2.86 |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |                 1 |                   1 |            7    |         7    |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |                 1 |                   1 |            1.63 |         1.63 |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |                 1 |                   1 |            9.33 |         9.33 |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |                 2 |                   2 |           19.98 |        19.98 |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |                 1 |                   1 |            6.78 |         6.78 |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |                 1 |                   1 |            3.78 |         3.78 |

# %%
# Mission 6: obtain the same result of Mission 5 using apply lambda
# Try both methods to apply to the whole dataset and apply to selected columns

# pas compris la question

# Add your code here

books["ratio_lambda"] = books.apply(lambda row: round((row["text_reviews_count"] / row["ratings_count"]) * 100, 2), axis = 1)

# %%
print(books.to_markdown())
# Out:
# |    |   bookID | title                                                                                                        | authors                    |   average_rating | isbn       |        isbn13 | language_code   |     num_pages |   ratings_count |   text_reviews_count | publication_date   | publisher          | reviews_opinion   |   NB_Authors_Func |   NB_Authors_lambda |   comment_ratio |   ratio_func |   ratio_lambda |
# |---:|---------:|:-------------------------------------------------------------------------------------------------------------|:---------------------------|-----------------:|:-----------|--------------:|:----------------|--------------:|----------------:|---------------------:|:-------------------|:-------------------|:------------------|------------------:|--------------------:|----------------:|-------------:|---------------:|
# |  0 |        1 | Harry Potter and the Half-Blood Prince (Harry Potter  #6)                                                    | J.K. Rowling/Mary GrandPré |             4.57 | 0439785960 | 9780439785969 | eng             |           652 |         2095690 |                27591 | 9/16/2006          | Scholastic Inc.    | very good         |                 2 |                   2 |            1.32 |         1.32 |           1.32 |
# |  1 |        2 | Harry Potter and the Order of the Phoenix (Harry Potter  #5)                                                 | J.K. Rowling/Mary GrandPré |             4.49 | 0439358078 | 9780439358071 | eng             |           870 |         2153167 |                29221 | 9/1/2004           | Scholastic Inc.    | good              |                 2 |                   2 |            1.36 |         1.36 |           1.36 |
# |  2 |        4 | Harry Potter and the Chamber of Secrets (Harry Potter  #2)                                                   | J.K. Rowling               |             4.42 | 0439554896 | 9780439554893 | eng             |           352 |            6333 |                  244 | 11/1/2003          | Scholastic         | good              |                 1 |                   1 |            3.85 |         3.85 |           3.85 |
# |  3 |        5 | Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)                                                  | J.K. Rowling/Mary GrandPré |             4.56 | 043965548X | 9780439655484 | eng             |           435 |         2339585 |                36325 | 5/1/2004           | Scholastic Inc.    | very good         |                 2 |                   2 |            1.55 |         1.55 |           1.55 |
# |  4 |        8 | Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)                                                       | J.K. Rowling/Mary GrandPré |             4.78 | 0439682584 | 9780439682589 | eng             |          2690 |           41428 |                  164 | 9/13/2004          | Scholastic         | very good         |                 2 |                   2 |            0.4  |         0.4  |           0.4  |
# |  5 |        9 | Unauthorized Harry Potter Book Seven News: "Half-Blood Prince" Analysis and Speculation                      | W. Frederick Zimmerman     |             3.74 | 0976540606 | 9780976540601 | en-US           |           152 |              19 |                    1 | 4/26/2005          | Nimble Books       | neutral           |                 1 |                   1 |            5.26 |         5.26 |           5.26 |
# |  6 |       10 | Harry Potter Collection (Harry Potter  #1-6)                                                                 | J.K. Rowling               |             4.73 | 0439827604 | 9780439827607 | eng             |          3342 |           28242 |                  808 | 9/12/2005          | Scholastic         | very good         |                 1 |                   1 |            2.86 |         2.86 |           2.86 |
# |  7 |       12 | The Ultimate Hitchhiker's Guide: Five Complete Novels and One Story (Hitchhiker's Guide to the Galaxy  #1-5) | Douglas Adams              |             4.38 | 0517226952 | 9780517226957 | eng             |           815 |            3628 |                  254 | 11/1/2005          | Gramercy Books     | good              |                 1 |                   1 |            7    |         7    |           7    |
# |  8 |       13 | The Ultimate Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1-5)                       | Douglas Adams              |             4.38 | 0345453743 | 9780345453747 | eng             |           815 |          249558 |                 4080 | 4/30/2002          | Del Rey Books      | good              |                 1 |                   1 |            1.63 |         1.63 |           1.63 |
# |  9 |       14 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams              |             4.22 | 1400052920 | 9781400052929 | eng             |           215 |            4930 |                  460 | 8/3/2004           | Crown              | good              |                 1 |                   1 |            9.33 |         9.33 |           9.33 |
# | 10 |       16 | The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy  #1)                                  | Douglas Adams/Stephen Fry  |             4.22 | 0739322206 | 9780739322208 | eng             |             6 |            1266 |                  253 | 3/23/2005          | Random House Audio | good              |                 2 |                   2 |           19.98 |        19.98 |          19.98 |
# | 11 |       18 | The Ultimate Hitchhiker's Guide (Hitchhiker's Guide to the Galaxy  #1-5)                                     | Douglas Adams              |             4.38 | 0517149257 | 9780517149256 | eng             |           815 |            2877 |                  195 | 1/17/1996          | Wings Books        | good              |                 1 |                   1 |            6.78 |         6.78 |           6.78 |
# | 12 |       21 | A Short History of Nearly Everything                                                                         | Bill Bryson                |             4.21 | 076790818X | 9780767908184 | eng             |           544 |          248558 |                 9396 | 9/14/2004          | Broadway Books     | good              |                 1 |                   1 |            3.78 |         3.78 |           3.78 |

# %%
print(books.dtypes)
# Out:
# bookID                  int64
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                  int64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# reviews_opinion        object
# NB_Authors_Func         int64
# NB_Authors_lambda       int64
# comment_ratio         float64
# ratio_func            float64
# ratio_lambda          float64
# dtype: object

# %%
# Mission 7: extract the year from the publication_date column. How many years of publications are recorded in this dataset? Which are them?
# Add your code here
# def extract(x):
#   year =[]
#   for element in x:
#     annee = element.split('/')
#     for result in annee :
#       if len(result) == 4:
#         year.append(result)

books["year"] = pd.to_datetime(books["publication_date"]).dt.year

# %%
combien = books["year"].nunique()
print(combien)
# Out:
# 6

# %%
lesquelles = books["year"].unique()
print(lesquelles)
# Out:
# [2006 2004 2003 2005 2002 1996]
